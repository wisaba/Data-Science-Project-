# %% [markdown]
# #Pandas

# %%
import pandas as pd

calories = {"day1":400,"day2":360,"day3":700}
my_series = pd.Series(calories)
my_series
# Out:
# day1    400
# day2    360
# day3    700
# dtype: int64

# %%
import pandas as pd

cal = [400,360,700]
series = pd.Series(cal, index =["day1","day2","day3"])
print(series)
# Out:
# day1    400
# day2    360
# day3    700
# dtype: int64

# %%
import numpy as np

my_data = {"a":[1,2,2],"b":[4,5,6],"c":[7,8,9]}
df = pd.DataFrame(data =my_data)
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  2  6  9

# %%
my_df = pd.read_csv("my_data.csv")
my_df
# Out:
#              x         y       sai         u         v     Omega  alpha_eh  \
# 0     0.000016 -0.000694  0.013293  0.000233 -0.006926  0.132176  5.484579
# 1     0.000251 -0.002746  0.052293  0.001739 -0.013581  0.255768  5.445806
# 2     0.001187 -0.005993  0.114588  0.005211 -0.019380  0.364287  5.383801
# 3     0.003377 -0.010026  0.196776  0.010412 -0.023613  0.454430  5.301844
# 4     0.007183 -0.014204  0.295112  0.016395 -0.025958  0.525923  5.203556
# ...        ...       ...       ...       ...       ...       ...       ...
# 8971  3.439422 -3.927756  5.539761  0.039040  0.008860 -0.198355 -0.129574
# 8972  3.445904 -3.931995  5.503155  0.037119  0.005509 -0.168186 -0.118798
# 8973  3.451604 -3.936532  5.471817  0.035199  0.003608 -0.145490 -0.107957
# 8974  3.456718 -3.941144  5.443952  0.033417  0.002742 -0.133309 -0.097475
# 8975  3.479078 -3.965854  5.320897  0.031373  0.001893 -0.113825 -0.058776
#
#             Xe        Ye            u1         u2
# ...

# %%
titanic = pd.read_csv("titanic.csv")
titanic.sort_values("Age")
titanic.drop("Cabin",axis=1,inplace=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.iloc[542,:]
# Out:
# PassengerId                                  543
# Survived                                       0
# Pclass                                         3
# Name           Andersson, Miss. Sigrid Elisabeth
# Sex                                       female
# Age                                         11.0
# SibSp                                          4
# Parch                                          2
# Ticket                                    347082
# Fare                                      31.275
# Embarked                                       S
# Name: 542, dtype: object

# %%
result = titanic.query("Survived==1")
result.shape[0]
answer = titanic.query("Sex==male"and"Pclass==1"and"Survived==0")
answer.shape[0]
# Out:
# 549

# %%
df1 = pd.DataFrame(np.array([[1,2,8],[55,6,3],[18,15,9]]),columns=['a','b','c'])
df2 = pd.DataFrame(np.array([[63,91,20],[4,88,6],[70,56,14]]),columns=['a','b','c'])
pd.concat([df1,df2],axis=1)
# Out:
#     a   b  c   a   b   c
# 0   1   2  8  63  91  20
# 1  55   6  3   4  88   6
# 2  18  15  9  70  56  14
