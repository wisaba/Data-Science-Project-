# %% [markdown]
# Pre_processing

# %%
import pandas as pd

titanic = pd.read_csv('titanic.csv')
titanic.head()
titanic.drop(["Name","SibSp","Embarked","PassengerId","Ticket"],inplace=True,axis=1 )
titanic
# Out:
#      Survived  Pclass     Sex   Age  Parch     Fare Cabin
# 0           0       3    male  22.0      0   7.2500   NaN
# 1           1       1  female  38.0      0  71.2833   C85
# 2           1       3  female  26.0      0   7.9250   NaN
# 3           1       1  female  35.0      0  53.1000  C123
# 4           0       3    male  35.0      0   8.0500   NaN
# ..        ...     ...     ...   ...    ...      ...   ...
# 886         0       2    male  27.0      0  13.0000   NaN
# 887         1       1  female  19.0      0  30.0000   B42
# 888         0       3  female   NaN      2  23.4500   NaN
# 889         1       1    male  26.0      0  30.0000  C148
# 890         0       3    male  32.0      0   7.7500   NaN
#
# [891 rows x 7 columns]

# %%
titanic.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# Parch         0
# Fare          0
# Cabin       687
# dtype: int64

# %%
new_titanic = titanic.dropna(axis=1)
new_titanic.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Parch       0
# Fare        0
# dtype: int64

# %%
new_titanic2 = titanic.dropna(axis=0)
new_titanic2.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# Parch       0
# Fare        0
# Cabin       0
# dtype: int64

# %%
new_titanic.shape
# Out:
# (891, 5)

# %%
new_titanic2.shape
# Out:
# (185, 7)

# %%
import pandas as pd
banking = pd.read_csv('Banking_Marketing.csv')
banking
# Out:
#          age          job  marital            education  default housing loan  \
# 0       44.0  blue-collar  married             basic.4y  unknown     yes   no
# 1       53.0   technician  married              unknown       no      no   no
# 2       28.0   management   single    university.degree       no     yes   no
# 3       39.0     services  married          high.school       no      no   no
# 4       55.0      retired  married             basic.4y       no     yes   no
# ...      ...          ...      ...                  ...      ...     ...  ...
# 41194  104.0      retired  married          high.school  unknown      no  yes
# 41195    2.0    housemaid  married                Basic  unknown      no    n
# 41196    3.0       admin.   single    university.degree  unknown     yes    y
# 41197    NaN   technician  married  professional.course       no      no    n
# 41198    NaN      student   single          high.school       no      no    n
#
# ...

# %%
banking2 = banking
banking2['age'] = banking2['age'].fillna(banking2['age'].mean)
banking2.tail()
# Out:
#                                                      age         job  marital  \
# 41194                                              104.0     retired  married
# 41195                                                2.0   housemaid  married
# 41196                                                3.0      admin.   single
# 41197  <bound method Series.mean of 0         44.0\n1...  technician  married
# 41198  <bound method Series.mean of 0         44.0\n1...     student   single
#
#                  education  default housing loan    contact month day_of_week  \
# 41194          high.school  unknown      no  yes  telephone   jun         thu
# 41195                Basic  unknown      no    n        NaN   may         thu
# 41196    university.degree  unknown     yes    y        NaN   may         wed
# 41197  professional.course       no      no    n  telephone   oct         tue
# 41198          high.school       no      no    n  telephone   may         fri
#
# ...

# %%
import pandas as pd
titanic3 = pd.read_csv('titanic.csv')
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
titanic3['Sex'] = le.fit_transform(titanic3['Sex'])
titanic3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
titanic3 = pd.read_csv('titanic.csv')

ohe = OneHotEncoder()
categorical_columns = ["Sex"]
categorical_data = titanic3[categorical_columns]
encoded_data = ohe.fit_transform(categorical_data)
titanic4 = pd.DataFrame(encoded_data.toarray(),columns=ohe.get_feature_names_out())
pd.concat([titanic3,titanic4],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd 
titanic5 = pd.get_dummies(titanic3, columns=['Sex'],dtype=int)
titanic5
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import pandas as pd
titanic3 = pd.read_csv("titanic.csv")
titanic6 = titanic3

ss = StandardScaler()
data_scaler = ['Age','Fare']
titanic6[data_scaler] = ss.fit_transform(titanic6[data_scaler])
titanic6
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male -0.530377
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  0.571831
# 2                               Heikkinen, Miss. Laina  female -0.254825
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  0.365167
# 4                             Allen, Mr. William Henry    male  0.365167
# ..                                                 ...     ...       ...
# ...
